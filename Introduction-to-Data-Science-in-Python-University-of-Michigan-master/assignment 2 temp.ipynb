# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
df
# Out:
#                                               # Summer  Gold  Silver  Bronze  \
# Afghanistan (AFG)                                   13     0       0       2
# Algeria (ALG)                                       12     5       2       8
# Argentina (ARG)                                     23    18      24      28
# Armenia (ARM)                                        5     1       2       9
# Australasia (ANZ) [ANZ]                              2     3       4       5
# Australia (AUS) [AUS] [Z]                           25   139     152     177
# Austria (AUT)                                       26    18      33      35
# Azerbaijan (AZE)                                     5     6       5      15
# Bahamas (BAH)                                       15     5       2       5
# Bahrain (BRN)                                        8     0       0       1
# Barbados (BAR) [BAR]                                11     0       0       1
# ...

# %%
names_ids = df.index.str.split('\s\(') # split the index by '('
df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)
df = df.drop('Totals')

# %%
df
# Out:
#                                   # Summer  Gold  Silver  Bronze  Total  \
# Afghanistan                             13     0       0       2      2
# Algeria                                 12     5       2       8     15
# Argentina                               23    18      24      28     70
# Armenia                                  5     1       2       9     12
# Australasia                              2     3       4       5     12
# Australia                               25   139     152     177    468
# Austria                                 26    18      33      35     86
# Azerbaijan                               5     6       5      15     26
# Bahamas                                 15     5       2       5     12
# Bahrain                                  8     0       0       1      1
# Barbados                                11     0       0       1      1
# Belarus                                  5    12      24      39     75
# ...

# %%
def answer_zero():
    # This function returns the row for Afghanistan, which is a Series object. The assignment
    # question description will tell you the general format the autograder is expecting
    return df.iloc[0]

# You can examine what your function returns by calling it in the cell. If you have questions
# about the assignment formats, check out the discussion forums for any FAQs
answer_zero()
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %%
for col in df.columns:
    print(col)
# Out:
# # Summer
# Gold
# Silver
# Bronze
# Total
# # Winter
# Gold.1
# Silver.1
# Bronze.1
# Total.1
# # Games
# Gold.2
# Silver.2
# Bronze.2
# Combined total
# ID

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
# Out:
# # Summer
# Gold
# Silver
# Bronze
# Total
# # Winter
# Gold.1
# Silver.1
# Bronze.1
# Total.1
# # Games
# Gold.2
# Silver.2
# Bronze.2
# Combined total
# ID

# %%
#DataFrame.max(axis=None, skipna=None, level=None, numeric_only=None, **kwargs)
#df1 = df.loc[:,['# Summer',df.columns[1]]]
df1 = df.loc[:,['Gold']]
df1
# Out:
#                                   Gold
# Afghanistan                          0
# Algeria                              5
# Argentina                           18
# Armenia                              1
# Australasia                          3
# Australia                          139
# Austria                             18
# Azerbaijan                           6
# Bahamas                              5
# Bahrain                              0
# Barbados                             0
# Belarus                             12
# Belgium                             37
# Bermuda                              0
# Bohemia                              0
# Botswana                             0
# Brazil                              23
# British West Indies                  0
# Bulgaria                            51
# Burundi                              1
# Cameroon                             3
# Canada                              59
# Chile                                2
# ...

# %%
max?
df.loc[:,[df.columns[1]]].max()
# Out:
# Gold    976
# dtype: int64

# %%
maximum = df1.max()
maximum
# Out:
# Gold    976
# dtype: int64

# %%
maximum[0]
# Out:
# 976

# %%
df1 = pd.DataFrame(df['Gold'] == maximum[0])
df1
# Out:
#                                    Gold
# Afghanistan                       False
# Algeria                           False
# Argentina                         False
# Armenia                           False
# Australasia                       False
# Australia                         False
# Austria                           False
# Azerbaijan                        False
# Bahamas                           False
# Bahrain                           False
# Barbados                          False
# Belarus                           False
# Belgium                           False
# Bermuda                           False
# Bohemia                           False
# Botswana                          False
# Brazil                            False
# British West Indies               False
# Bulgaria                          False
# Burundi                           False
# Cameroon                          False
# Canada                            False
# ...

# %%
#df.index[df['BoolCol'] == True].tolist() BoolCol is a series of boolean values T or Fs
#df.index[df['BoolCol']].tolist()

# %%
lol = df1.index[df1['Gold']==True].tolist()
df1.index[df1['Gold']==True].tolist()[0]
# Out:
# 'United States'

# %%
lol
# Out:
# ['United States']

# %%
lol[0]
# Out:
# 'United States'

# %%
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
# Out:
# # Summer
# Gold
# Silver
# Bronze
# Total
# # Winter
# Gold.1
# Silver.1
# Bronze.1
# Total.1
# # Games
# Gold.2
# Silver.2
# Bronze.2
# Combined total
# ID

# %%
# temp = pd.DataFrame()
# for i in range(len(df.index)):
#     tempseries = pd.Series({[df.index[i]]:(df.loc[df.index[i],df.columns[1]]-df.loc[df.index[i],df.columns[6]]), })
#     temp.append(tempseries)
# temp
# #     print(df.index[i])
# # df.T.loc['diffsumwin'] = None
# # df
# #maximum = df.loc[:,[df.columns[1]]].max()
# #df

# %%
#to add a new column do this
# df['sumwintdiff'] = pd.Series(df.loc[:,df.columns[1]]-df.loc[:,df.columns[6]], index=df.index)
df['sumwintdiff'] = pd.Series(df.loc[:,'Gold']-df.loc[:,'Gold.1'], index=df.index)
#     minimum = df.loc[:,[df.columns[16]]].min()
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID  sumwintdiff
# ...

# %%
maximum = df.loc[:,'sumwintdiff'].max()
minimum = df.loc[:,'sumwintdiff'].min()
print(maximum)
df1 = pd.DataFrame(df['sumwintdiff'] == maximum)#minimum[0])
lol = df1.index[df1['sumwintdiff']==True].tolist()
print(lol[0])
# Out:
# 880
# United States

# %%
df['sumwintsum'] = pd.Series(df.loc[:,df.columns[1]]+df.loc[:,df.columns[6]], index=df.index)
df['ratiodiffsum'] = pd.Series(df.loc[:,df.columns[16]]/df.loc[:,df.columns[17]], index=df.index)
df
# Out:
#                                   # Summer  Gold  Silver  Bronze  Total  \
# Afghanistan                             13     0       0       2      2
# Algeria                                 12     5       2       8     15
# Argentina                               23    18      24      28     70
# Armenia                                  5     1       2       9     12
# Australasia                              2     3       4       5     12
# Australia                               25   139     152     177    468
# Austria                                 26    18      33      35     86
# Azerbaijan                               5     6       5      15     26
# Bahamas                                 15     5       2       5     12
# Bahrain                                  8     0       0       1      1
# Barbados                                11     0       0       1      1
# Belarus                                  5    12      24      39     75
# ...

# %%
maximum = df.loc[:,[df.columns[18]]].max()
df1 = pd.DataFrame(df['ratiodiffsum'] == maximum[0])#minimum[0])
lol = df1.index[df1['ratiodiffsum']==True].tolist()
array = []
for i in range(len(lol)):
    array.append(lol[i])
string= str(array)
print(string)
type(string)
# Out:
# ['Algeria', 'Argentina', 'Armenia', 'Australasia', 'Azerbaijan', 'Bahamas', 'Brazil', 'Burundi', 'Cameroon', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'Ethiopia', 'Georgia', 'Greece', 'Grenada', 'Hong Kong', 'Hungary', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Jamaica', 'Kenya', 'North Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico', 'Mongolia', 'Morocco', 'Mozambique', 'New Zealand', 'Nigeria', 'Pakistan', 'Panama', 'Peru', 'Portugal', 'Romania', 'Russian Empire', 'Serbia', 'Serbia and Montenegro', 'South Africa', 'Suriname', 'Syria', 'Chinese Taipei', 'Thailand', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda', 'United Arab Emirates', 'Uruguay', 'Venezuela', 'Yugoslavia', 'Zimbabwe', 'Mixed team']
# str

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
# Out:
# # Summer
# Gold
# Silver
# Bronze
# Total
# # Winter
# Gold.1
# Silver.1
# Bronze.1
# Total.1
# # Games
# Gold.2
# Silver.2
# Bronze.2
# Combined total
# ID
# sumwintdiff
# sumwintsum
# ratiodiffsum

# %%
df['totalgold'] = pd.Series(df.loc[:,'Gold']+df.loc[:,'Gold.1']+df.loc[:,'Gold.2'], index=df.index)
df['totalsilver'] = pd.Series(df.loc[:,'Silver']+df.loc[:,'Silver.1']+df.loc[:,'Silver.2'], index=df.index)
df['totalbronze'] = pd.Series(df.loc[:,'Bronze']+df.loc[:,'Bronze.1']+df.loc[:,'Bronze.2'], index=df.index)
df['Points'] = pd.Series(3*(df.loc[:,'totalgold'])+2*(df.loc[:,'totalsilver'])+df.loc[:,'totalbronze'], index=df.index)
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1   ...    Bronze.2  Combined total  \
# Afghanistan         0         0        0   ...           2               2
# Algeria             0         0        0   ...           8              15
# Argentina           0         0        0   ...          28              70
# Armenia             0         0        0   ...           9              12
# Australasia         0         0        0   ...           5              12
#
#               ID  sumwintdiff  sumwintsum ratiodiffsum  totalgold  \
# ...

# %%
df1 = pd.Series(df.loc[:,'Points'])

# %%
print(df1)
# Out:
# Afghanistan                             4
# Algeria                                54
# Argentina                             260
# Armenia                                32
# Australasia                            44
# Australia                            1846
# Austria                              1138
# Azerbaijan                             86
# Bahamas                                48
# Bahrain                                 2
# Barbados                                2
# Belarus                               308
# Belgium                               552
# Bermuda                                 2
# Bohemia                                10
# Botswana                                4
# Brazil                                368
# British West Indies                     4
# Bulgaria                              822
# Burundi                                 6
# Cameroon                               24
# Canada                               1692
# ...

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
def answer_four():
    df['totalgold'] = pd.Series(df.loc[:,'Gold']+df.loc[:,'Gold.1']+df.loc[:,'Gold.2'], index=df.index)
    df['totalsilver'] = pd.Series(df.loc[:,'Silver']+df.loc[:,'Silver.1']+df.loc[:,'Silver.2'], index=df.index)
    df['totalbronze'] = pd.Series(df.loc[:,'Bronze']+df.loc[:,'Bronze.1']+df.loc[:,'Bronze.2'], index=df.index)
    df['Points'] = pd.Series(3*(df.loc[:,'totalgold'])+2*(df.loc[:,'totalsilver'])+df.loc[:,'totalbronze'], index=df.index)
    df1 = pd.Series(df.loc[:,'Points'])
    return df1
fff = answer_four()
type(fff)
# for i in range(len(fff.index)):
#     print(fff.values)
# Out:
# pandas.core.series.Series

# %%
#  for i in range(len(df1.index)):
#         print(df1.values[i])

# %%
def haha():
    return 2
a= haha()
b=haha
print(b)
type(b)
print(a)
# Out:
# <function haha at 0x000002941C3AF378>
# 2

# %%
census_df = pd.read_csv('census.csv')
census_df.head()
# size(census_df)     this is wrong
census_df.size
# Out:
# 319300

# %%
census_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
census_df.shape
# Out:
# (3193, 100)

# %%
census_df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
census_df1 = census_df.set_index(['STNAME', 'CTYNAME'])
census_df1.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Alabama             40       3         6      1       0
#         Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama               4779736            4780127          4785161
#         Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012     ...       \
# ...

# %%
# X      Y     Z                                
# bar   one    a   -0.007381 -0.365315 -0.024817
#              b   -1.219794  0.370955 -0.795125
# baz   three  a    0.145578  1.428502 -0.408384
#              b   -0.249321 -0.292967 -1.849202
#       two    a   -0.249321 -0.292967 -1.849202
#       four   a    0.211234 -0.967123  1.202234
# foo   one    b   -1.046479 -1.250595  0.781722
#              a    1.314373  0.333150  0.133331
# qux   one    c    0.716789  0.616471 -0.298493
#       two    b    0.385795 -0.915417 -1.367644

# %%
#  df.reset_index().groupby('X')['Y'].nunique()

# %%
numctyin_st = census_df.groupby('STNAME')['CTYNAME'].nunique()

# %%
numctyin_st
# Out:
# STNAME
# Alabama                  68
# Alaska                   30
# Arizona                  16
# Arkansas                 76
# California               59
# Colorado                 65
# Connecticut               9
# Delaware                  4
# District of Columbia      1
# Florida                  68
# Georgia                 160
# Hawaii                    6
# Idaho                    45
# Illinois                103
# Indiana                  93
# Iowa                    100
# Kansas                  106
# Kentucky                121
# Louisiana                65
# Maine                    17
# Maryland                 25
# Massachusetts            15
# Michigan                 84
# Minnesota                88
# Mississippi              83
# Missouri                116
# Montana                  57
# Nebraska                 94
# Nevada                   18
# New Hampshire            11
# New Jersey               22
# New Mexico               34
# New York                 63
# ...

# %%
type(numctyin_st)
# Out:
# pandas.core.series.Series

# %%
maxim = numctyin_st.max()
ans = numctyin_st.idxmax()
print(ans)
# Out:
# Texas

# %%
numctyin_st = pd.DataFrame(numctyin_st.values == maxim)
numctyin_st
# Out:
#         0
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41  False
# 42  False
# 43  False
# 44  False
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False
# 50  False

# %%
# loll = numctyin_st.index[numctyin_st == True].tolist()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-337-9c61194e8bf1> in <module>()
# ----> 1 loll = numctyin_st.index[numctyin_st == True].tolist()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2078
#    2079         key = com._values_from_object(key)
# -> 2080         result = getitem(key)
#    2081         if not is_scalar(result):
#    2082             return promote(result)
#
# IndexError: too many indices for array

# %%
counties_df = census_df[census_df['SUMLEV'] == 50]
x = counties_df.groupby('STNAME').count()['SUMLEV']
ans = x.idxmax()
print(ans)
# Out:
# SUMLEV                   Texas
# REGION                   Texas
# DIVISION                 Texas
# STATE                    Texas
# COUNTY                   Texas
# CTYNAME                  Texas
# CENSUS2010POP            Texas
# ESTIMATESBASE2010        Texas
# POPESTIMATE2010          Texas
# POPESTIMATE2011          Texas
# POPESTIMATE2012          Texas
# POPESTIMATE2013          Texas
# POPESTIMATE2014          Texas
# POPESTIMATE2015          Texas
# NPOPCHG_2010             Texas
# NPOPCHG_2011             Texas
# NPOPCHG_2012             Texas
# NPOPCHG_2013             Texas
# NPOPCHG_2014             Texas
# NPOPCHG_2015             Texas
# BIRTHS2010               Texas
# BIRTHS2011               Texas
# BIRTHS2012               Texas
# BIRTHS2013               Texas
# BIRTHS2014               Texas
# BIRTHS2015               Texas
# DEATHS2010               Texas
# DEATHS2011               Texas
# DEATHS2012               Texas
# DEATHS2013               Texas
# ...

# %%
counties_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
top_counties_df = census_df.sort_values(by=['STNAME','CENSUS2010POP'],ascending=False).groupby('STNAME').head(3)

# %%
top_counties_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY                STNAME  \
# 3169      40       4         8     56       0               Wyoming
# 3180      50       4         8     56      21               Wyoming
# 3182      50       4         8     56      25               Wyoming
# 3096      40       2         3     55       0             Wisconsin
# 3137      50       2         3     55      79             Wisconsin
# 3109      50       2         3     55      25             Wisconsin
# 3040      40       3         5     54       0         West Virginia
# 3060      50       3         5     54      39         West Virginia
# 3042      50       3         5     54       3         West Virginia
# 3000      40       4         9     53       0            Washington
# 3017      50       4         9     53      33            Washington
# 3027      50       4         9     53      53            Washington
# 2866      40       3         5     51       0              Virginia
# ...

# %%
ans = top_counties_df.groupby('STNAME').sum().sort_values(by='CENSUS2010POP').head(3).index.tolist()
ans
# Out:
# ['Wyoming', 'Vermont', 'North Dakota']

# %%
counties_df  = pd.read_csv('census.csv')

# %%
counties_df = counties_df[census_df['SUMLEV'] == 50]
counties_df
# Out:
# C:\Users\sudhe\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# ...

# %%
counties_df['pop_change'] = abs(counties_df['POPESTIMATE2015'] - counties_df['POPESTIMATE2014'])+abs(counties_df['POPESTIMATE2014'] - counties_df['POPESTIMATE2013'])+abs(counties_df['POPESTIMATE2013'] - counties_df['POPESTIMATE2012'])+abs(counties_df['POPESTIMATE2012'] - counties_df['POPESTIMATE2011'])+abs(counties_df['POPESTIMATE2011'] - counties_df['POPESTIMATE2010'])

# %%
a = max(counties_df['pop_change'])
a
# Out:
# 429841

# %%
ans = counties_df['CTYNAME'][counties_df['pop_change']==a].tolist()

# %%
ans
# Out:
# ['Harris County']

# %%
ans[0]
# Out:
# 'Harris County'

# %%
counties_df = census_df[census_df['SUMLEV'] == 50]

# %%
ans = counties_df[((counties_df['REGION']==1)|(counties_df['REGION']==2))&(counties_df['CTYNAME']=='Washington County')&(counties_df['POPESTIMATE2015']>counties_df['POPESTIMATE2014'])][['STNAME','CTYNAME']]

# %%
ans
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County
